# %% [markdown]
# <a href="https://colab.research.google.com/github/nrenzan/Handwritten_Text_Recognization/blob/main/Csvgeneration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

train_image_dir = '/content/drive/MyDrive/DL/images-final/images/train'
valid_image_dir = '/content/drive/MyDrive/DL/images-final/images/validate'
test_image_dir = '/content/drive/MyDrive/DL/images-final/images/test'

# %%
import os
import pandas as pd

def create_dataframe_from_directory(directory_path):
    file_data = {'FILENAME': [], 'IDENTITY': []}

    for root, dirs, files in os.walk(directory_path):
        for file_name in files:
            full_path = os.path.join(root, file_name)
            relative_path = full_path.replace(directory_path, '')  # Replace the directory path with an empty string
            relative_path = relative_path.lstrip(os.path.sep)  # Remove leading separator if present
            file_data['FILENAME'].append(relative_path)
            file_data['IDENTITY'].append(file_name)

    dataframe = pd.DataFrame(file_data)
    return dataframe

# Create DataFrame from the directory
file_dataframe = create_dataframe_from_directory(train_image_dir)

# Display the created DataFrame
print(file_dataframe.head())
# Out:
#                            FILENAME                          IDENTITY
# 0           Diethyl triptamin-2.png           Diethyl triptamin-2.png
# 1               Phenmetrazine-5.png               Phenmetrazine-5.png
# 2               Phenmetrazine-4.png               Phenmetrazine-4.png
# 3                      Evogen-2.png                      Evogen-2.png
# 4  Lycergic Acid Diethylamide-2.png  Lycergic Acid Diethylamide-2.png

# %%
file_dataframe['IDENTITY'] = [element[:-4] for element in file_dataframe['IDENTITY']]

# %%
file_dataframe
# Out:
#                               FILENAME                      IDENTITY
# 0              Diethyl triptamin-2.png           Diethyl triptamin-2
# 1                  Phenmetrazine-5.png               Phenmetrazine-5
# 2                  Phenmetrazine-4.png               Phenmetrazine-4
# 3                         Evogen-2.png                      Evogen-2
# 4     Lycergic Acid Diethylamide-2.png  Lycergic Acid Diethylamide-2
# ...                                ...                           ...
# 2168              Ethyl morphine-3.png              Ethyl morphine-3
# 2169                  Phentanyle-1.png                  Phentanyle-1
# 2170                 Etomorphine-1.png                 Etomorphine-1
# 2171              Ethyl morphine-2.png              Ethyl morphine-2
# 2172              Ethyl morphine-5.png              Ethyl morphine-5
#
# [2173 rows x 2 columns]

# %%
# prompt: Now write a code to take dataframe csv for file_dataframe dataframe.

file_dataframe.to_csv('train_refined.csv', index=False)

# %%
file_dataframe_valid = create_dataframe_from_directory(valid_image_dir)
file_dataframe_valid['IDENTITY'] = [element[:-4] for element in file_dataframe_valid['IDENTITY']]
file_dataframe_valid
# Out:
#                                    FILENAME  \
# 0                           Triazolam-2.png
# 1                           Triazolam-5.png
# 2                            Zolpidem-5.png
# 3                         Proparidine-3.png
# 4                           Triazolam-4.png
# ..                                      ...
# 191                Protamine Sulphate-1.png
# 192                       Triamterene-3.png
# 193  Vitamin D. as Single preparation-4.png
# 194  Vitamin D. as Single preparation-3.png
# 195  Vitamin D. as Single preparation-2.png
#
#                                IDENTITY
# 0                           Triazolam-2
# 1                           Triazolam-5
# 2                            Zolpidem-5
# 3                         Proparidine-3
# 4                           Triazolam-4
# ..                                  ...
# 191                Protamine Sulphate-1
# 192                       Triamterene-3
# 193  Vitamin D. as Single preparation-4
# ...

# %%
file_dataframe_valid.to_csv('valid_refined.csv', index=False)

# %%
file_dataframe_test = create_dataframe_from_directory(test_image_dir)
file_dataframe_test['IDENTITY'] = [element[:-4] for element in file_dataframe_test['IDENTITY']]
file_dataframe_test
# Out:
#                      FILENAME              IDENTITY
# 0             Etorphine-2.png           Etorphine-2
# 1    Dextropropoxyphene-2.png  Dextropropoxyphene-2
# 2              Fentanyl-1.png            Fentanyl-1
# 3    Dextropropoxyphene-4.png  Dextropropoxyphene-4
# 4               Codeine-3.png             Codeine-3
# ..                        ...                   ...
# 469          Thiacetazone.png          Thiacetazone
# 470       Triethanolamine.png       Triethanolamine
# 471           Talbutamide.png           Talbutamide
# 472    Trianyle Cipromine.png    Trianyle Cipromine
# 473       Triflupromazine.png       Triflupromazine
#
# [474 rows x 2 columns]

# %%
file_dataframe_test.to_csv('test_refined.csv', index=False)
